# %% [markdown]
# # Algerian Forest Fires Dataset 🔥
#
# ## 📘 Data Set Information
#
# #The dataset includes **244 instances** regrouping data from two regions of Algeria:
# - **Bejaia region** located in the northeast of Algeria
# - **Sidi Bel-Abbes region** located in the northwest of Algeria
#
# Each region contributes **122 instances**.
#
#  **Time Period:** June 2012 to September 2012
#  **Attributes:** 11 features + 1 output (class)
#
# Out of 244 instances:
# - **138** belong to the *Fire* class
# - **106** belong to the *Not Fire* class

# %% [markdown]
# ##### Attribute Information
# ## 🌡️ Attribute Information
#
# 1. **Date**: (DD/MM/YYYY) — Day, month ('June' to 'September'), year (2012)
# 2. **Temp**: Temperature at noon (°C) — 22 to 42
# 3. **RH**: Relative Humidity (%) — 21 to 90
# 4. **Ws**: Wind Speed (km/h) — 6 to 29
# 5. **Rain**: Total rainfall (mm) — 0 to 16.8
# 6. **FFMC**: Fine Fuel Moisture Code (28.6 to 92.5)
# 7. **DMC**: Duff Moisture Code (1.1 to 65.9)
# 8. **DC**: Drought Code (7 to 220.4)
# 9. **ISI**: Initial Spread Index (0 to 18.5)
# 10. **BUI**: Buildup Index (1.1 to 68)
# 11. **FWI**: Fire Weather Index (0 to 31.1)
# 12. **Classes**: Fire / Not Fire

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# dataset=pd.read_csv("Algerian_forest_fires_dataset_UPDATE.csv")
dataset=pd.read_csv("Algerian_forest_fires_dataset_UPDATE.csv",header=1) 
#ye krne se index aa gya vrna direct day se col start hota

# %%
dataset.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %% [markdown]
# # Data Cleaning
# ### Check for null values
# data.isnull().sum()
# ### Remove or rename unwanted columns (if any)
# data.columns = data.columns.str.strip()
# ### Drop empty rows or NaN values if they exist
# data.dropna(inplace=True)
# ### Check basic info
# data.info()

# %%
## missing values
dataset.isnull()
# Out:
#        day  month   year  Temperature     RH     Ws  Rain    FFMC    DMC  \
# 0    False  False  False        False  False  False  False  False  False
# 1    False  False  False        False  False  False  False  False  False
# 2    False  False  False        False  False  False  False  False  False
# 3    False  False  False        False  False  False  False  False  False
# 4    False  False  False        False  False  False  False  False  False
# ..     ...    ...    ...          ...    ...    ...    ...    ...    ...
# 241  False  False  False        False  False  False  False  False  False
# 242  False  False  False        False  False  False  False  False  False
# 243  False  False  False        False  False  False  False  False  False
# 244  False  False  False        False  False  False  False  False  False
# 245  False  False  False        False  False  False  False  False  False
#
#         DC    ISI    BUI    FWI  Classes
# 0    False  False  False  False      False
# ...

# %%
dataset.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
dataset.isnull().any()
# Out:
# day            False
# month           True
# year            True
# Temperature     True
#  RH             True
#  Ws             True
# Rain            True
# FFMC            True
# DMC             True
# DC              True
# ISI             True
# BUI             True
# FWI             True
# Classes         True
# dtype: bool

# %%
dataset.isnull().any(axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 241    False
# 242    False
# 243    False
# 244    False
# 245    False
# Length: 246, dtype: bool

# %%
dataset[dataset.isnull().any(axis=1)]
#row wise check kr rhe h ki kon si row me atleast one Null NaN value h
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %% [markdown]
# the dataset is converted into two sets based on region from 122th index, we can make a new column
# based on the region
# - 1 : 'Bejaia Region Dataset'
# - 1 : 'Sidi-Bel Abbes Region Dataset'
# - add new column with region

# %%
dataset.loc[:122,"Region"]=0
dataset.loc[122:,"Region"]=1
df=dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       246 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 29.0+ KB

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire        0.0
# 1  not fire        0.0
# 2  not fire        0.0
# 3  not fire        0.0
# 4  not fire        0.0

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 0    0.5   not fire        0.0
# ...

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes    Region
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN     1.0
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN     1.0

# %%
df[['Region']] = df[['Region']].astype(int)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes    Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
df.tail()
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 241  6.5       fire          1
# 242    0   not fire          1
# 243  0.2   not fire          1
# 244  0.7   not fire          1
# 245  0.5  not fire           1

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
df=df.dropna()

# %%
df.head(123)
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  \
# 0     01     06  2012           29   57   18      0  65.7  3.4   7.6  1.3
# 1     02     06  2012           29   61   13    1.3  64.4  4.1   7.6    1
# 2     03     06  2012           26   82   22   13.1  47.1  2.5   7.1  0.3
# 3     04     06  2012           25   89   13    2.5  28.6  1.3   6.9    0
# 4     05     06  2012           27   77   16      0  64.8    3  14.2  1.2
# ..   ...    ...   ...          ...  ...  ...    ...   ...  ...   ...  ...
# 118   27     09  2012           31   66   11      0  85.7  8.3  24.9    4
# 119   28     09  2012           32   47   14    0.7  77.5  7.1   8.8  1.8
# 120   29     09  2012           26   80   16    1.8  47.4  2.9   7.7  0.3
# 121   30     09  2012           25   78   14    1.4    45  1.9   7.5  0.2
# 123  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI
#
#      BUI  FWI    Classes    Region
# 0    3.4  0.5  not fire          0
# ...

# %%
#removing null values
df=df.dropna().reset_index(drop=True)
#isse index proper formate me aa jata h after drop the row otherwise index remain same although 
#row was deleted

# %%
df.head(124)
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI  \
# 0     01     06  2012           29   57   18      0  65.7  3.4   7.6  1.3
# 1     02     06  2012           29   61   13    1.3  64.4  4.1   7.6    1
# 2     03     06  2012           26   82   22   13.1  47.1  2.5   7.1  0.3
# 3     04     06  2012           25   89   13    2.5  28.6  1.3   6.9    0
# 4     05     06  2012           27   77   16      0  64.8    3  14.2  1.2
# ..   ...    ...   ...          ...  ...  ...    ...   ...  ...   ...  ...
# 119   28     09  2012           32   47   14    0.7  77.5  7.1   8.8  1.8
# 120   29     09  2012           26   80   16    1.8  47.4  2.9   7.7  0.3
# 121   30     09  2012           25   78   14    1.4    45  1.9   7.5  0.2
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI
# 123   01     06  2012           32   71   12    0.7  57.1  2.5   8.2  0.6
#
#      BUI  FWI    Classes    Region
# 0    3.4  0.5  not fire          0
# ...

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.iloc[[122]]
#ye bhi row ek proper record nii h to hm isko drop krenge qki same column name aa rha h data me jo ki proper rcord nii h
#jb aap record check krenge ye daaset to index 124 125 126 me dikh jayega ye Q kiya gya
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    Region
# 122  FWI  Classes         1

# %%
# df=df.drop(122).reset_index(drop=False)
df=df.drop(122).reset_index(drop=True)

# %%
df.head(123)
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...  ...  ...
# 118  27    09  2012          31  66  11     0  85.7  8.3  24.9    4    9  4.1
# 119  28    09  2012          32  47  14   0.7  77.5  7.1   8.8  1.8  6.8  0.9
# 120  29    09  2012          26  80  16   1.8  47.4  2.9   7.7  0.3    3  0.1
# 121  30    09  2012          25  78  14   1.4    45  1.9   7.5  0.2  2.4  0.1
# 122  01    06  2012          32  71  12   0.7  57.1  2.5   8.2  0.6  2.8  0.2
#
#        Classes    Region
# ...

# %%
df.reset_index()
df.head(123)
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...  ...  ...
# 118  27    09  2012          31  66  11     0  85.7  8.3  24.9    4    9  4.1
# 119  28    09  2012          32  47  14   0.7  77.5  7.1   8.8  1.8  6.8  0.9
# 120  29    09  2012          26  80  16   1.8  47.4  2.9   7.7  0.3    3  0.1
# 121  30    09  2012          25  78  14   1.4    45  1.9   7.5  0.2  2.4  0.1
# 122  01    06  2012          32  71  12   0.7  57.1  2.5   8.2  0.6  2.8  0.2
#
#        Classes    Region
# ...

# %%
df.reset_index(drop=True)
df.head(123)
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...  ...  ...
# 118  27    09  2012          31  66  11     0  85.7  8.3  24.9    4    9  4.1
# 119  28    09  2012          32  47  14   0.7  77.5  7.1   8.8  1.8  6.8  0.9
# 120  29    09  2012          26  80  16   1.8  47.4  2.9   7.7  0.3    3  0.1
# 121  30    09  2012          25  78  14   1.4    45  1.9   7.5  0.2  2.4  0.1
# 122  01    06  2012          32  71  12   0.7  57.1  2.5   8.2  0.6  2.8  0.2
#
#        Classes    Region
# ...

# %%
# by defalut isne new index create kr diya and old one ko index col bna diya h isko drop krna pdega
# df=df.drop(columns=['index'])

# %%
df.head(123)
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...  ...  ...
# 118  27    09  2012          31  66  11     0  85.7  8.3  24.9    4    9  4.1
# 119  28    09  2012          32  47  14   0.7  77.5  7.1   8.8  1.8  6.8  0.9
# 120  29    09  2012          26  80  16   1.8  47.4  2.9   7.7  0.3    3  0.1
# 121  30    09  2012          25  78  14   1.4    45  1.9   7.5  0.2  2.4  0.1
# 122  01    06  2012          32  71  12   0.7  57.1  2.5   8.2  0.6  2.8  0.2
#
#        Classes    Region
# ...

# %%
df.iloc[[122]]
# 122 index pr proper data h
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 122  01    06  2012          32  71  12   0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#        Classes    Region
# 122  not fire          1

# %%
df.columns
#yha hm log observe krenge ki RH me phle space h Rain and classes me bad me space h
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
#fix spaces in column names
df.columns=df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 28.6+ KB

# %%
# here we observe that all numerical feature excpet classes are object now 
# we convert this object into integer

# %% [markdown]
# # Changes the required columns as integer data type

# %%
df[['month','day','year','Temperature','RH','Ws']]=df[['month','day','year','Temperature','RH','Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(7), object(8)
# memory usage: 28.6+ KB

# %%
# yha hm observe krenge krenge ki inn feature ko chhod k baki k feature me float value h excpt fire b/c it is object  isiliye sbko int me nii convert kiya
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18     0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6    1  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9    0  1.7
# 4    5      6  2012           27  77  16     0  64.8    3  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3    0  not fire          0
# 4  0.5  not fire          0

# %% [markdown]
# # changing other columns to float data datatype

# %%
objects = [features for features in df.columns if df[features].dtypes=='O']
# object ko list ke andr daal diya

# %%
objects
# Out:
# ['Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes']

# %%
# ab isko flaot me convert krenge
for i in objects:
    if i!='Classes':
        df[i]=df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.6+ KB

# %%
objects
# Out:
# ['Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes']

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# ...

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
## Let save the cleaned dataset , that file is used for trin the model further
df.to_csv('Algerian_forest_fires_cleaned_dataset_updated.csv',index=False)

# %%
# df.to_csv('Algerian_forest_firedCleanedwith index.csv')
# # isme index ko alg se ek column assume kr leta h

# %% [markdown]
# # EDA

# %%
#drop day month and year
df_copy=df.drop(['day','month','year'],axis=1)

# %%
df_copy
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
#           Classes  Region
# 0     not fire          0
# 1     not fire          0
# 2     not fire          0
# 3     not fire          0
# 4     not fire          0
# ...

# %%
df_copy['Classes'].value_counts()
#It counts how many times each unique value appears in a column.
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
df_copy.describe(include='all')
#unique classes only 2 honi chahiye thi but here unique classes 8 h to 
#hmko bus 2 classes chahiye fire->1 and not fire->0
# Out:
#         Temperature          RH          Ws        Rain        FFMC  \
# count    243.000000  243.000000  243.000000  243.000000  243.000000
# unique          NaN         NaN         NaN         NaN         NaN
# top             NaN         NaN         NaN         NaN         NaN
# freq            NaN         NaN         NaN         NaN         NaN
# mean      32.152263   62.041152   15.493827    0.762963   77.842387
# std        3.628039   14.828160    2.811385    2.003207   14.349641
# min       22.000000   21.000000    6.000000    0.000000   28.600000
# 25%       30.000000   52.500000   14.000000    0.000000   71.850000
# 50%       32.000000   63.000000   15.000000    0.000000   83.300000
# 75%       35.000000   73.500000   17.000000    0.500000   88.300000
# max       42.000000   90.000000   29.000000   16.800000   96.000000
#
#                DMC          DC         ISI         BUI         FWI  Classes  \
# ...

# %% [markdown]
# # Handling categorical values

# %%
# # Encode class labels: Fire -> 1, Not Fire -> 0
# df_copy['Classes'] = df_copy['Classes'].map({'fire':1, 'not fire':0})

# # Verify encoding
# df_copy['Classes'].value_counts()

# %%
#encoding of categories in classes
df_copy['Classes'] = np.where(df_copy['Classes'].str.contains('not fire'),0,1)

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0       0

# %%
df_copy.head(124)
# Out:
#      Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  \
# 0             29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0
# 1             29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0
# 2             26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0
# 3             25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0
# 4             27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0
# ..           ...  ..  ..   ...   ...  ...   ...  ...  ...  ...      ...
# 119           32  47  14   0.7  77.5  7.1   8.8  1.8  6.8  0.9        0
# 120           26  80  16   1.8  47.4  2.9   7.7  0.3  3.0  0.1        0
# 121           25  78  14   1.4  45.0  1.9   7.5  0.2  2.4  0.1        0
# 122           32  71  12   0.7  57.1  2.5   8.2  0.6  2.8  0.2        0
# 123           30  73  13   4.0  55.7  2.7   7.8  0.6  2.9  0.2        0
#
#      Region
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# ...

# %%
df_copy.tail()
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 238       1
# 239       1
# 240       1
# 241       1
# 242       1

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
# Distribution of Target Variable
sns.countplot(x='Classes', data=df_copy, color='skyblue')
plt.title("Fire vs Not Fire Distribution")
plt.show()

# %%
sns.countplot(x='Classes', data=df_copy, hue='Classes', palette='Set2', legend=False)
plt.title("Fire vs Not Fire Distribution")
plt.show()

# %%
# Pairplot of numerical features
sns.pairplot(df_copy, hue='Classes', diag_kind='kde')
plt.show()

# %%
# Correlation Heatmap
plt.figure(figsize=(12,7))
sns.heatmap(df_copy.corr(), annot=True, cmap='coolwarm')
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
## plot density plot for all features
plt.style.use('seaborn')
df_copy.hist(bins=50,figsize=(20,15))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\style\core.py:129, in use(style)
#     128 try:
# --> 129     style = _rc_params_in_file(style)
#     130 except OSError as err:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\__init__.py:906, in _rc_params_in_file(fname, transform, fail_on_error)
#     905 rc_temp = {}
# --> 906 with _open_file_or_url(fname) as fd:
#     907     try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\__init__.py:883, in _open_file_or_url(fname)
#     882 fname = os.path.expanduser(fname)
# ...

# %% [markdown]
# # 🟢 9. Univariate & Bivariate Analysis

# %%
# Temperature distribution
plt.figure(figsize=(6,4))
sns.histplot(df_copy['Temperature'], kde=True, color='orange')
plt.title("Temperature Distribution")
plt.show()

# %%
# Relation between Temperature and FWI
plt.figure(figsize=(6,4))
sns.scatterplot(x='Temperature', y='FWI', hue='Classes', data=df_copy, palette='Set1')
plt.title("Temperature vs FWI")
plt.show()

# %% [markdown]
# # 🟢 Correlation Analysis

# %%
# Correlation matrix for numeric features
df_copy.corr(numeric_only=True)
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
plt.figure(figsize=(12,7))
sns.heatmap(df_copy.corr(numeric_only=True), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap of Algerian Forest Fire Features", fontsize=14, weight='bold')
plt.show()

# %%
df_copy.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
sns.heatmap(df_copy.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(df['FWI'],color='green')
# Out:
# <Axes: ylabel='FWI'>

# %%
# # df['Classes'] = np.where(df['Classes'].str.contains('not fire'),0,)
# # sns.heatmap(df.corr(),annot=True,numeric_only=True)
# # Encode Classes column
# # df_copy['Classes'] = np.where(df_copy['Classes'].str.contains('not fire', case=False, na=False),
# #                               'not fire', 'fire')
# # Example: if 0 means not fire and 1 means fire
# df_copy['Classes'] = df_copy['Classes'].replace({0: 'not fire', 1: 'fire'})

# # Region column (1 for Bejaia, 2 for Sidi Bel-Abbes)
# df_copy.loc[:122, 'Region'] = 0
# df_copy.loc[122:, 'Region'] = 1

# %%
## Montly fire analysis

# # 🔹 Filter for Bejaia region
# df_temp = df_copy.loc[df_copy['Region'] == 0]

# plt.subplots(figsize=(13,6))
# sns.set_style("whitegrid")

# sns.countplot(x='month', hue='Classes', data=df_temp, palette='coolwarm')

# plt.xlabel("Months", weight='bold')
# plt.ylabel("Number of Fires", weight='bold')
# plt.title("🔥 Fire Analysis of Bejaia Region", fontsize=14, weight='bold')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[155], line 9
#       6 plt.subplots(figsize=(13,6))
#       7 sns.set_style("whitegrid")
# ----> 9 sns.countplot(x='month', hue='Classes', data=df_temp, palette='coolwarm')
#      11 plt.xlabel("Months", weight='bold')
#      12 plt.ylabel("Number of Fires", weight='bold')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:2631, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628 elif x is not None and y is not None:
#    2629     raise TypeError("Cannot pass values for both `x` and `y`.")
# -> 2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    2634     order=order,
# ...

# %%
# # 🔹 Filter for Sidi Bel-Abbes region
# df_temp2 = df_copy.loc[df_copy['Region'] == 1]

# plt.subplots(figsize=(13,6))
# sns.set_style("whitegrid")

# sns.countplot(x='month', hue='Classes', data=df_temp2, palette='coolwarm')

# plt.xlabel("Months", weight='bold')
# plt.ylabel("Number of Fires", weight='bold')
# plt.title("🔥 Fire Analysis of Sidi Bel-Abbes Region", fontsize=14, weight='bold')
# plt.show()

# %% [markdown]
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# # Step 1: Encode 'Classes' column (string-safe conversion)
# df['Classes'] = df['Classes'].astype(str)
# df['Classes'] = np.where(df['Classes'].str.contains('not fire', case=False, na=False),
#                          'not fire', 'fire')
#
# # Step 2: Encode Region (1 for Bejaia, 2 for Sidi Bel-Abbes)
# df.loc[:122, 'Region'] = 1
# df.loc[122:, 'Region'] = 2
#
# # Step 3: Correlation Heatmap
# plt.figure(figsize=(10,6))
# sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
# plt.title("Feature Correlation Heatmap", fontsize=14, fontweight='bold')
# plt.show()
#
# # Step 4: Boxplot for FWI
# sns.boxplot(x=df['FWI'], color='green')
# plt.title("Boxplot of Fire Weather Index (FWI)")
# plt.show()
#
# # Step 5: Monthly Fire Analysis
# # Make sure you still have the 'month' column in df (since df_copy removed it)
# plt.figure(figsize=(13,6))
# sns.set_style("whitegrid")
# sns.countplot(x='month', hue='Classes', data=df)
# plt.xlabel("Months", weight='bold')
# plt.ylabel("Number of Fires", weight='bold')
# plt.title("Monthly Fire Analysis of Bejaia & Sidi Bel-Abbes Regions", weight='bold')
# plt.show()

# %%
# 🔹 Filter for Bejaia region
df_temp = df.loc[df['Region'] == 1]

plt.subplots(figsize=(13,6))
sns.set_style("whitegrid")

sns.countplot(x='month', hue='Classes', data=df_temp, palette='coolwarm')

plt.xlabel("Months", weight='bold')
plt.ylabel("Number of Fires", weight='bold')
plt.title("🔥 Fire Analysis of Bejaia Region", fontsize=14, weight='bold')
plt.show()
# Out:
# C:\Users\sapps\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128293 (\N{FIRE}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 🔹 Filter for Sidi Bel-Abbes region
df_temp2 = df.loc[df['Region'] == 2]

plt.subplots(figsize=(13,6))
sns.set_style("whitegrid")

sns.countplot(x='month', hue='Classes', data=df_temp2, palette='coolwarm')

plt.xlabel("Months", weight='bold')
plt.ylabel("Number of Fires", weight='bold')
plt.title("🔥 Fire Analysis of Sidi Bel-Abbes Region", fontsize=14, weight='bold')
plt.show()
# Out:
# C:\Users\sapps\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128293 (\N{FIRE}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# it obseverd that most of the fire occure in August in both reagion and
